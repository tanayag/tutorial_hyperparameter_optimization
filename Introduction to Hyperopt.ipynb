# %% [markdown]
# ## Hyperopt is a Hyperparamter Optimization Library
#
# It Minimizes a function f(x1,x2....,xn) when (x1,x2....,xn) belong to some Range

# %%
from hyperopt import hp, tpe, fmin
from hyperopt.mongoexp import MongoTrials
# hp is the function which will create a range for the function parameters
# tpe is the Tree-structured Parzen Estimator Algorithm, which we use instead of Grid/Random search as dicussed
# fmin is the function that will take in the function that is to be optimized, the range of parameters

# %%
def objective_function(args):  
    
    '''define the function which will take the argument                            
    and return the equation that is to be minimized.
    taking the arguments
    returning the equation
    '''
    
    x,y = args[0],args[0]  
    return x**2 - y**2

# %%
# space = {'x':hp.uniform('x',-2,2),     
#          #defining the range for x
         
#          'y':hp.uniform('y',-3,1)}      
#         #defining the range for y

# %%
space = [hp.uniform('x',-2,2), hp.uniform('y',-3,1)]

# %%
best_param_60eval = fmin(objective_function ,space ,algo=tpe.suggest ,max_evals=60)
# using tpe to get the minimum value of f(x,y) when x <- (-2,2)
#                                               and y <- (-3,1)

# %%
print(best_param_60eval)
# Out:
# {'y': -2.1603749211456584, 'x': 1.3375448481033194}

# %%
#almost similar result for 100 evals
best_param_100eval = fmin(objective_function ,space ,algo=tpe.suggest ,max_evals=100)
print(best_param_100eval)
# Out:
# {'y': -2.9914118485184074, 'x': 0.22298709904380568}

# %% [markdown]
# ## Understanding and Creating Search Space for hyperopt
# Unlike sklearn's grid search hyperopt.fmin's search space must be an hp object. We'll look at some important range functions and how to use them

# %% [markdown]
# Fmin function allow us to pass only one argument to objective function as can be seen in above example, the we are supposed to extract the parameters from the argument.
#
# we can use the above code like this as well:
#
# ```
# def objective_function(args):
#     x,y = args[0],args[1]
#     return x**2 - y**2
#
# space = [hp.uniform('x',-2,2),hp.uniform('y',-3,1)]
# #or
# space = ([hp.uniform('x',-2,2),hp.uniform('y',-3,1)])
#
# ```
#
# ### Lets look at some hyperopt space functions on the official wiki page here:
# https://github.com/hyperopt/hyperopt/wiki/FMin#21-parameter-expressions

# %% [markdown]
# ## We'll now use some complex spaces in the following sklearn examples and Compare Grid Search and tpe for optimization of

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd

df = pd.read_csv('iris.csv')

# %%
df.head()  #our data
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
l = LabelEncoder()
df['species'] = l.fit_transform(df['species'])

x = df.drop('species',axis=1)
y = df['species']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Using Grid Search

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC

df = pd.read_csv('iris.csv')

l = LabelEncoder()
df['species'] = l.fit_transform(df['species'])
x = df.drop('species',axis=1)
y = df['species']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)


def Grid(model):
    
    
    '''
    the Grid function creates a dictionaries of choices of hyperparameters 
    to be used in the Grid Search
    '''
    
    
    if model == 'KNeighborsClassifier':
        parameters = {'n_neighbors':[3,11],
                  'algorithm':['ball_tree','kd_tree'],
                  'leaf_size':[1,50],
                  'metric':["euclidean","manhattan","chebyshev","minkowski"]}
   
    if model == 'SVC':
        parameters ={ 'kernel':['rbf','poly','rbf','sigmoid'],
            'degree':[1,15],
            'gamma':[0.001,10000]}
    
    return parameters



def GridSearch(model):
    
    '''
    GridSearch is a wrapper for sklearn's GridSearchCV as per model case
    '''
    
    if model == "KNeighboursClassifier":
        parameters = Grid("KNeighborsClassifier")
        knc=KNeighborsClassifier()
        global clf
        clf = GridSearchCV(knc,parameters)
    
    if model == "SVC":
        parameters = Grid("SVC")
        svc = SVC()
        clf = GridSearchCV(svc,parameters)

        
    clf.fit(x_train,y_train)
    
    return clf


clf1 = GridSearch("SVC")
clf2 = GridSearch("KNeighborsClassifier")

# y_pred_train = clf1.predict(x_train)    
# loss = mean_squared_error(y_train,y_pred_train)

# print("Test Score:",clf.score(x_test,y_test))
print("Train Score for SVC:",clf1.score(x_train,y_train))
print("Test Score for SVC ",clf1.score(x_test,y_test))
print("\n")
print("Train Score for KNeighborsClassifier:",clf2.score(x_train,y_train))
print("Test Score for KNeighborsClassifier",clf2.score(x_test,y_test))
print("\n=================")
# Out:
# /home/greatskull/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/greatskull/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# ('Train Score for SVC:', 0.9833333333333333)
# ('Test Score for SVC ', 0.9666666666666667)
#
#
# ('Train Score for KNeighborsClassifier:', 0.9833333333333333)
# ('Test Score for KNeighborsClassifier', 0.9666666666666667)
#
# =================
# /home/greatskull/anaconda2/lib/python2.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %% [markdown]
# ### Using Hyperopt

# %%
from sklearn import datasets
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from hyperopt import tpe, hp, fmin
from sklearn.metrics import mean_squared_error
iris = datasets.load_iris()
x = iris.data
y = iris.target
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

def objective_func(args):
    
    
    '''
    the objective function that has to be minimized as per the target 'loss'
    '''
    
    if args['model']==KNeighborsClassifier:
        n_neighbors = args['param']['n_neighbors']
        algorithm = args['param']['algorithm']
        leaf_size = args['param']['leaf_size']
        metric = args['param']['metric']
        clf = KNeighborsClassifier(n_neighbors=n_neighbors,
                               algorithm=algorithm,
                               leaf_size=leaf_size,
                               metric=metric,
                               )
    elif args['model']==SVC:
        C = args['param']['C']
        kernel = args['param']['kernel']
        degree = args['param']['degree']
        gamma = args['param']['gamma']
        clf = SVC(C=C, kernel=kernel, degree=degree,gamma=gamma)
    
    
    clf.fit(x_train,y_train)
    
    y_pred_train = clf.predict(x_train)
    
    loss = mean_squared_error(y_train,y_pred_train)
    
    print(args)
    
    print("Test Score:",clf.score(x_test,y_test))
    print("Train Score:",clf.score(x_train,y_train))
    print("\n=================")
    
    return loss



#space is the choices of hyperparameters for the objective function
space = hp.choice('classifier',[
        {'model': KNeighborsClassifier,
        'param': {'n_neighbors': hp.choice('n_neighbors',range(3,11)),
                  'algorithm':hp.choice('algorithm',['ball_tree','kd_tree']),
                  'leaf_size':hp.choice('leaf_size',range(1,50)),
                  'metric':hp.choice('metric', ["euclidean","manhattan","chebyshev","minkowski"])}
        },
    
        {'model': SVC,
        'param':{'C':hp.lognormal('C',0,1),
        'kernel':hp.choice('kernel',['rbf','poly','rbf','sigmoid']),
        'degree':hp.choice('degree',range(1,15)),
        'gamma':hp.uniform('gamma',0.001,10000)}
        }
        ])


best_classifier = fmin(objective_func, space, algo=tpe.suggest, max_evals=100)
print(best_classifier)
# Out:
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.83394525164318, 'degree': 11, 'gamma': 3682.1995052940583}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 0.37432705867293947, 'degree': 8, 'gamma': 3494.8518713642625}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 10, 'metric': 'chebyshev', 'leaf_size': 7, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.345345931635596, 'degree': 4, 'gamma': 8304.660527374122}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 7, 'metric': 'minkowski', 'leaf_size': 16, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 5, 'metric': 'minkowski', 'leaf_size': 48, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 7, 'metric': 'minkowski', 'leaf_size': 16, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 9, 'metric': 'manhattan', 'leaf_size': 47, 'algorithm': 'ball_tree'}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 2.6977450204728832, 'degree': 1, 'gamma': 6040.248028039189}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.9833333333333333)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.9470139717679539, 'degree': 14, 'gamma': 3000.315714136671}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.2517084617839605, 'degree': 14, 'gamma': 176.76018280315628}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 1.0352804575542531, 'degree': 12, 'gamma': 17.101418938313977}}
# ('Test Score:', 0.9)
# ('Train Score:', 0.8916666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.7078126097973043, 'degree': 11, 'gamma': 4831.755247957543}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 8, 'metric': 'manhattan', 'leaf_size': 16, 'algorithm': 'ball_tree'}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.95)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 10, 'metric': 'euclidean', 'leaf_size': 40, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9583333333333334)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.9179594033849185, 'degree': 14, 'gamma': 7429.589235025124}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 0.3632012062960231, 'degree': 10, 'gamma': 3394.989912429417}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 1.5603640754477184, 'degree': 14, 'gamma': 1311.1750009749287}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 7, 'metric': 'euclidean', 'leaf_size': 9, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 0.40156583150292074, 'degree': 1, 'gamma': 8300.681296511513}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.7816954544309114, 'degree': 11, 'gamma': 6655.937412218347}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.7515443862118661, 'degree': 13, 'gamma': 9515.518795440075}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.9781415431862209, 'degree': 3, 'gamma': 5357.155647426891}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.6881224160220422, 'degree': 11, 'gamma': 6557.923080906}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.06435922106669044, 'degree': 13, 'gamma': 9900.343535573304}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.5817081483373017, 'degree': 2, 'gamma': 4300.985205030558}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.6040347656320817, 'degree': 9, 'gamma': 1737.6321030794898}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.6268671437304255, 'degree': 6, 'gamma': 6237.179524994579}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.5019451042899654, 'degree': 2, 'gamma': 4272.319605091687}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.35833333333333334)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.5122913417063999, 'degree': 9, 'gamma': 1709.7066450703778}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.6916666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.8540491145438845, 'degree': 6, 'gamma': 2723.9951625235494}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.1540329489375676, 'degree': 6, 'gamma': 5719.258002614032}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.6047495815683267, 'degree': 5, 'gamma': 7618.860477245281}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.8798267683836863, 'degree': 6, 'gamma': 2441.4981500067197}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 4, 'metric': 'chebyshev', 'leaf_size': 35, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.975)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 5.111256865596206, 'degree': 5, 'gamma': 7378.2223006281465}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 6, 'metric': 'manhattan', 'leaf_size': 8, 'algorithm': 'kd_tree'}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.95)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.1069162053520394, 'degree': 4, 'gamma': 8540.484173036417}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 3, 'metric': 'chebyshev', 'leaf_size': 13, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.975)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 0.7948693870795591, 'degree': 13, 'gamma': 9468.352988812952}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.6492571981950419, 'degree': 7, 'gamma': 4081.4584971764034}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 9, 'metric': 'euclidean', 'leaf_size': 39, 'algorithm': 'kd_tree'}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.975)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.2969380121968412, 'degree': 4, 'gamma': 8645.779797148085}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.962790475754147, 'degree': 7, 'gamma': 4049.355576082128}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 6, 'metric': 'euclidean', 'leaf_size': 45, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.95)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.3576101552992523, 'degree': 8, 'gamma': 646.0415914315508}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 2.178043286217525, 'degree': 7, 'gamma': 3651.422649867919}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.9730979159631501, 'degree': 3, 'gamma': 5201.965808198092}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 3, 'metric': 'chebyshev', 'leaf_size': 2, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.975)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.0539849159767247, 'degree': 3, 'gamma': 4956.448839037919}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.827398433376136, 'degree': 3, 'gamma': 5549.493159850686}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 4, 'metric': 'manhattan', 'leaf_size': 5, 'algorithm': 'kd_tree'}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.95)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.6866800332512476, 'degree': 11, 'gamma': 6892.149389337405}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 0.5496078296320196, 'degree': 11, 'gamma': 6341.506439787647}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.7205722130735794, 'degree': 12, 'gamma': 3409.503855443817}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.2449397721720661, 'degree': 11, 'gamma': 4640.589499533753}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 8, 'metric': 'minkowski', 'leaf_size': 24, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.42469420299118865, 'degree': 5, 'gamma': 7992.209844874326}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 0.43852257662000266, 'degree': 2, 'gamma': 2467.0962363641565}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.9980137431778748, 'degree': 7, 'gamma': 721.9363099707653}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.3563357996437319, 'degree': 2, 'gamma': 2983.7999444205752}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.35833333333333334)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 5, 'metric': 'manhattan', 'leaf_size': 3, 'algorithm': 'ball_tree'}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.95)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 3.6918550588648538, 'degree': 10, 'gamma': 1793.6515411088408}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.30714019120952696, 'degree': 1, 'gamma': 3733.7086821057474}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.5667838569995511, 'degree': 2, 'gamma': 4577.824397716998}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.4779655381520881, 'degree': 8, 'gamma': 1916.4670225938896}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.35833333333333334)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.6370036680127072, 'degree': 9, 'gamma': 6084.6435636754695}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.6282824711193081, 'degree': 9, 'gamma': 25.74120814420803}}
# ('Test Score:', 0.7)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.7582548606212044, 'degree': 6, 'gamma': 747.4728679610797}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.8907993047508294, 'degree': 6, 'gamma': 2656.914559931133}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.8357985351417758, 'degree': 6, 'gamma': 2975.301196593237}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.0301471123349457, 'degree': 6, 'gamma': 5843.619431226144}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.1673427748858054, 'degree': 14, 'gamma': 5595.252762281596}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 1.2261717113873876, 'degree': 5, 'gamma': 7307.757838994048}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 1.3771275477555176, 'degree': 5, 'gamma': 9240.254354506975}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 1.5225413524160296, 'degree': 12, 'gamma': 7938.3351527396935}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 9, 'metric': 'chebyshev', 'leaf_size': 20, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9833333333333333)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.9363026732085623, 'degree': 13, 'gamma': 9948.851637635407}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.8869217221989237, 'degree': 10, 'gamma': 1295.4507043824242}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.8140036737387374, 'degree': 6, 'gamma': 6864.080267116852}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 4, 'metric': 'euclidean', 'leaf_size': 1, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.6687752321428637, 'degree': 5, 'gamma': 2396.889180663775}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 0.7207359972452941, 'degree': 1, 'gamma': 2143.805912007958}}
# ('Test Score:', 0.9666666666666667)
# ('Train Score:', 0.9833333333333333)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.7595906237424306, 'degree': 11, 'gamma': 5413.225003264806}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 17.95204042521338, 'degree': 4, 'gamma': 1325.6146094218834}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 8, 'metric': 'minkowski', 'leaf_size': 10, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 4.688281393535918, 'degree': 14, 'gamma': 3924.346425137443}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 7.525723815602343, 'degree': 8, 'gamma': 4374.498679147453}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'sigmoid', 'C': 21.0405190976011, 'degree': 11, 'gamma': 3146.5490578654308}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 6, 'metric': 'euclidean', 'leaf_size': 4, 'algorithm': 'kd_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.95)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.8545180673617891, 'degree': 6, 'gamma': 5020.376891459773}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 7.705031033134191, 'degree': 5, 'gamma': 3460.897972024736}}
# ('Test Score:', 1.0)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'poly', 'C': 10.240636607738633, 'degree': 12, 'gamma': 321.006465764337}}
# ('Test Score:', 0.36666666666666664)
# ('Train Score:', 0.325)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 2.7863363891517854, 'degree': 4, 'gamma': 8948.038864032076}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 10, 'metric': 'minkowski', 'leaf_size': 23, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9583333333333334)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 4.155110243237879, 'degree': 4, 'gamma': 8712.186490286054}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.1512367988037022, 'degree': 4, 'gamma': 7349.981774540064}}
# ('Test Score:', 0.3)
# ('Train Score:', 0.3416666666666667)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 0.518690185644059, 'degree': 9, 'gamma': 1203.0602966662182}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.svm.classes.SVC'>, 'param': {'kernel': 'rbf', 'C': 1.0873335669487205, 'degree': 7, 'gamma': 4765.397749611766}}
# ('Test Score:', 0.3)
# ('Train Score:', 1.0)
#
# =================
# {'model': <class 'sklearn.neighbors.classification.KNeighborsClassifier'>, 'param': {'n_neighbors': 3, 'metric': 'chebyshev', 'leaf_size': 33, 'algorithm': 'ball_tree'}}
# ('Test Score:', 1.0)
# ('Train Score:', 0.9666666666666667)
#
# =================
# {'kernel': 2, 'C': 0.83394525164318, 'gamma': 3682.1995052940583, 'classifier': 1, 'degree': 10}

# %% [markdown]
# ## Evaluations using MongoDB

# %% [markdown]
# In the docker environment we have provided, MongoDB is already installed.
# In order to parallelinzing evaluations with MongoDB we'll first start with creating the server
#
# `service mongod start`
#
# PS: note that in docker you have the root access, in ur system your command will start with sudo
#
# Compile your python Script

# %%
import math
from hyperopt import tpe, hp, fmin
from hyperopt.mongoexp import MongoTrials


trials = MongoTrials('mongo://localhost:27017/foo_db/jobs', exp_key='exp4')

best = fmin(math.cos, hp.uniform('x', -2, 2), trials=trials, algo=tpe.suggest, max_evals=20)

print(best)
# Out:
# {u'x': -1.8495872997740905}

# %% [markdown]
# Now that we have compiled the above script, we'll start the worker, we'll open another terminal and use the command below
#
#
# `hyperopt-mongo-worker --mongo=localhost:27017/foo_db --poll-interval=0.1`
#
#
# this worker will connect the script with the server and will handle the tasks

# %% [markdown]
# ## And now we'll show you the demo of a real life example that we solved using Hyperopt during our summer internship at MateLabs
