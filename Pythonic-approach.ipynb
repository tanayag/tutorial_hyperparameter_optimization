# %% [markdown]
# # Tuning The Hyperparameters  - Using A Naive Pythonic Approach

# %% [markdown]
# We will be using the boston dataset for the examples and the exercises.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge 
from sklearn.datasets import load_boston
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# We'll be using a train-test split of 80:20 for training and validation of the algorithm

# %%
X,y = load_boston(return_X_y=True)
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Lets have our own Simple Hyperparameter Tuner !!

# %%
def custom_hyperparameter_tuner( hyperparams_dict , algorithm , metric_score="r2_score" ):
    
    """
    Implementation of a Simple Loop Based 
    Hyperparameter Tuning based on the metric score, , 
    hyperparameter combinations and algorithms provided as arguments
    """
    
    if metric_score=="r2_score":
        
        """
        Based on the r2_score , it selects out the best hyperparameter out of all the hyperparameters 
        """
        
        best_hyperparams=None
        best_accuracy=-99999
        
        if algorithm=="Ridge":
            for i in hyperparams_dict:
                ridge = Ridge(alpha = i['alpha'])
                ridge.fit(x_train,y_train)
                y_pred = ridge.predict(x_test)
                score = r2_score(y_test , y_pred)
                print(str(i)+" gives r2_score: "+str(score))
                if score > best_accuracy:
                    best_accuracy=score
                    best_hyperparams=i
                    
        
        if algorithm=="KNearest":
            for i in hyperparams_dict:
                knearest=KNeighborsRegressor(n_neighbors=i['n_neighbors'],weights=i['weights'])
                knearest.fit(x_train,y_train)
                y_pred = knearest.predict(x_test)
                score = r2_score(y_test , y_pred)
                print(str(i)+" gives r2_score: "+str(score))
                if score > best_accuracy:
                    best_accuracy=score
                    best_hyperparams=i
            
            
#         if algorithm=="SVM Regressor":
#         """
#             1. Create a SVM Regressor for each of the choice sets in the hyperparams_dict
#             2. Fit it on X_train and predict on X_test 
#             3. Calculate r2_score and find the best hyperparams
#         """
        
    return (best_accuracy , best_hyperparams)

# %% [markdown]
# Create the Hyperparameter Combinations by using loops

# %%
def create_hyperparameter_dict( algorithm ):
    hyperparams_dict=[]
    if algorithm=="Ridge":
        """
        For Ridge , We have taken only one hyperparameter(alpha)'s hyperparameters .
        alpha: can be any value b/w 0 and 1
        """
        for i in range(1,100):
            hyperparams_dict.append({"alpha":i*0.01})
            i+=1
    
    if algorithm=="KNearest":
        """
        For KNearest Regressor , We have taken n_neighbors and weights as the hyperparameters
        n_neighbors: can have any integral value b/w 1 to no_of_samples
        weights: can be any one out of {"uniform","distance"}
        """
        weights=["uniform","distance"]
        for i in range(1,x_train.shape[0],5):
            for j in range(0,2,1):
                hyperparams_dict.append({"n_neighbors":i,"weights":weights[j]})


#     if algorithm=="SVMRegressor":
#         """
#         For SVM Regressor , take kernel , C(penality parameter) , max_iter  as the hyperparameters
#         kernel: can be any one out of {"linear","rbf","sigmoid"}
#         C: can be any value b/w 1 and 10 
#         max_iter: can be b/w (1,100)
#         """
            
    
    return hyperparams_dict

# %% [markdown]
# # We have our Hyperparameter Tuner !! Lets Test it

# %%
hyperparams_dict=create_hyperparameter_dict("KNearest")
hyperparams_dict2=create_hyperparameter_dict("Ridge")
# print(hyperparams_dict)
best_acc,best_hyperparams=custom_hyperparameter_tuner(hyperparams_dict,"KNearest","r2_score")
best_acc2,best_hyperparams2=custom_hyperparameter_tuner(hyperparams_dict2,"Ridge","r2_score")
# print(best_score)
print("Best Hyperparameters for KNearest: " +str(best_hyperparams)+" with r2_score: "+str(best_acc))
print("Best Hyperparameters for Ridge Regression: "+str(best_hyperparams2)+" with r2_score: "+str(best_acc2))
# Out:
# {'weights': 'uniform', 'n_neighbors': 1} gives r2_score: 0.2702325598524651
# {'weights': 'distance', 'n_neighbors': 1} gives r2_score: 0.2702325598524651
# {'weights': 'uniform', 'n_neighbors': 6} gives r2_score: 0.35917334579441773
# {'weights': 'distance', 'n_neighbors': 6} gives r2_score: 0.39913612195781145
# {'weights': 'uniform', 'n_neighbors': 11} gives r2_score: 0.3316851639617685
# {'weights': 'distance', 'n_neighbors': 11} gives r2_score: 0.3846740822593764
# {'weights': 'uniform', 'n_neighbors': 16} gives r2_score: 0.26048258297177385
# {'weights': 'distance', 'n_neighbors': 16} gives r2_score: 0.3383782837657625
# {'weights': 'uniform', 'n_neighbors': 21} gives r2_score: 0.21597922416282078
# {'weights': 'distance', 'n_neighbors': 21} gives r2_score: 0.30630206590040643
# {'weights': 'uniform', 'n_neighbors': 26} gives r2_score: 0.18560891557593617
# {'weights': 'distance', 'n_neighbors': 26} gives r2_score: 0.2817312200671872
# {'weights': 'uniform', 'n_neighbors': 31} gives r2_score: 0.1560405066297178
# {'weights': 'distance', 'n_neighbors': 31} gives r2_score: 0.2591542191711972
# {'weights': 'uniform', 'n_neighbors': 36} gives r2_score: 0.11815103293386964
# {'weights': 'distance', 'n_neighbors': 36} gives r2_score: 0.22940574886134601
# {'weights': 'uniform', 'n_neighbors': 41} gives r2_score: 0.09279037624947273
# {'weights': 'distance', 'n_neighbors': 41} gives r2_score: 0.2091178295604078
# {'weights': 'uniform', 'n_neighbors': 46} gives r2_score: 0.08319976783252536
# {'weights': 'distance', 'n_neighbors': 46} gives r2_score: 0.19943424850196723
# {'weights': 'uniform', 'n_neighbors': 51} gives r2_score: 0.06831579333150772
# {'weights': 'distance', 'n_neighbors': 51} gives r2_score: 0.18783354719541023
# {'weights': 'uniform', 'n_neighbors': 56} gives r2_score: 0.0683265544598689
# {'weights': 'distance', 'n_neighbors': 56} gives r2_score: 0.1848271709528373
# {'weights': 'uniform', 'n_neighbors': 61} gives r2_score: 0.06127967951264135
# {'weights': 'distance', 'n_neighbors': 61} gives r2_score: 0.17940754642223555
# {'weights': 'uniform', 'n_neighbors': 66} gives r2_score: 0.059100164425029966
# {'weights': 'distance', 'n_neighbors': 66} gives r2_score: 0.17488021750570126
# {'weights': 'uniform', 'n_neighbors': 71} gives r2_score: 0.058817067019603986
# {'weights': 'distance', 'n_neighbors': 71} gives r2_score: 0.1720885112038648
# {'weights': 'uniform', 'n_neighbors': 76} gives r2_score: 0.05578729393820925
# {'weights': 'distance', 'n_neighbors': 76} gives r2_score: 0.16873469049132106
# {'weights': 'uniform', 'n_neighbors': 81} gives r2_score: 0.05688878336364711
# {'weights': 'distance', 'n_neighbors': 81} gives r2_score: 0.16844758463762222
# {'weights': 'uniform', 'n_neighbors': 86} gives r2_score: 0.061033914258595834
# {'weights': 'distance', 'n_neighbors': 86} gives r2_score: 0.16814274609586854
# {'weights': 'uniform', 'n_neighbors': 91} gives r2_score: 0.06669230306072405
# {'weights': 'distance', 'n_neighbors': 91} gives r2_score: 0.16886232067609497
# {'weights': 'uniform', 'n_neighbors': 96} gives r2_score: 0.07105232872324863
# {'weights': 'distance', 'n_neighbors': 96} gives r2_score: 0.169630909399743
# {'weights': 'uniform', 'n_neighbors': 101} gives r2_score: 0.08213931997392065
# {'weights': 'distance', 'n_neighbors': 101} gives r2_score: 0.172869066523599
# {'weights': 'uniform', 'n_neighbors': 106} gives r2_score: 0.08412778912112262
# {'weights': 'distance', 'n_neighbors': 106} gives r2_score: 0.17309164324446458
# {'weights': 'uniform', 'n_neighbors': 111} gives r2_score: 0.0908752668587639
# {'weights': 'distance', 'n_neighbors': 111} gives r2_score: 0.17293266119720851
# {'weights': 'uniform', 'n_neighbors': 116} gives r2_score: 0.08986617634154415
# {'weights': 'distance', 'n_neighbors': 116} gives r2_score: 0.1731711092461683
# {'weights': 'uniform', 'n_neighbors': 121} gives r2_score: 0.0944439170599779
# {'weights': 'distance', 'n_neighbors': 121} gives r2_score: 0.17387256568688825
# {'weights': 'uniform', 'n_neighbors': 126} gives r2_score: 0.0947972452568947
# {'weights': 'distance', 'n_neighbors': 126} gives r2_score: 0.17286090188143255
# {'weights': 'uniform', 'n_neighbors': 131} gives r2_score: 0.09498474322930806
# {'weights': 'distance', 'n_neighbors': 131} gives r2_score: 0.17263458292744682
# {'weights': 'uniform', 'n_neighbors': 136} gives r2_score: 0.08961369476012016
# {'weights': 'distance', 'n_neighbors': 136} gives r2_score: 0.17124588052292555
# {'weights': 'uniform', 'n_neighbors': 141} gives r2_score: 0.08991142481771275
# {'weights': 'distance', 'n_neighbors': 141} gives r2_score: 0.17020735451435598
# {'weights': 'uniform', 'n_neighbors': 146} gives r2_score: 0.08993765976588686
# {'weights': 'distance', 'n_neighbors': 146} gives r2_score: 0.16952080246644685
# {'weights': 'uniform', 'n_neighbors': 151} gives r2_score: 0.08806089361252512
# {'weights': 'distance', 'n_neighbors': 151} gives r2_score: 0.16896356322893313
# {'weights': 'uniform', 'n_neighbors': 156} gives r2_score: 0.08704238815911414
# {'weights': 'distance', 'n_neighbors': 156} gives r2_score: 0.16840324873761792
# {'weights': 'uniform', 'n_neighbors': 161} gives r2_score: 0.08564373925899815
# {'weights': 'distance', 'n_neighbors': 161} gives r2_score: 0.1672191106382107
# {'weights': 'uniform', 'n_neighbors': 166} gives r2_score: 0.08130536317275361
# {'weights': 'distance', 'n_neighbors': 166} gives r2_score: 0.16588290723976729
# {'weights': 'uniform', 'n_neighbors': 171} gives r2_score: 0.07724332862887784
# {'weights': 'distance', 'n_neighbors': 171} gives r2_score: 0.16438570454345902
# {'weights': 'uniform', 'n_neighbors': 176} gives r2_score: 0.07571466231282376
# {'weights': 'distance', 'n_neighbors': 176} gives r2_score: 0.1638143816332931
# {'weights': 'uniform', 'n_neighbors': 181} gives r2_score: 0.07633431544560543
# {'weights': 'distance', 'n_neighbors': 181} gives r2_score: 0.1639366622783457
# {'weights': 'uniform', 'n_neighbors': 186} gives r2_score: 0.07542350074737347
# {'weights': 'distance', 'n_neighbors': 186} gives r2_score: 0.16347788295817622
# {'weights': 'uniform', 'n_neighbors': 191} gives r2_score: 0.07675578440428132
# {'weights': 'distance', 'n_neighbors': 191} gives r2_score: 0.16378041997465165
# {'weights': 'uniform', 'n_neighbors': 196} gives r2_score: 0.08129133183209147
# {'weights': 'distance', 'n_neighbors': 196} gives r2_score: 0.16460259317457226
# {'weights': 'uniform', 'n_neighbors': 201} gives r2_score: 0.0785936763371462
# {'weights': 'distance', 'n_neighbors': 201} gives r2_score: 0.1633321496714778
# {'weights': 'uniform', 'n_neighbors': 206} gives r2_score: 0.0722201799471025
# {'weights': 'distance', 'n_neighbors': 206} gives r2_score: 0.16136631032887905
# {'weights': 'uniform', 'n_neighbors': 211} gives r2_score: 0.06707738716446177
# {'weights': 'distance', 'n_neighbors': 211} gives r2_score: 0.15960275779025457
# {'weights': 'uniform', 'n_neighbors': 216} gives r2_score: 0.06677764080235027
# {'weights': 'distance', 'n_neighbors': 216} gives r2_score: 0.15953461417566306
# {'weights': 'uniform', 'n_neighbors': 221} gives r2_score: 0.06511118334864918
# {'weights': 'distance', 'n_neighbors': 221} gives r2_score: 0.15865670206857496
# {'weights': 'uniform', 'n_neighbors': 226} gives r2_score: 0.06448013604629665
# {'weights': 'distance', 'n_neighbors': 226} gives r2_score: 0.1583464562109016
# {'weights': 'uniform', 'n_neighbors': 231} gives r2_score: 0.06468415414864948
# {'weights': 'distance', 'n_neighbors': 231} gives r2_score: 0.1585384375869313
# {'weights': 'uniform', 'n_neighbors': 236} gives r2_score: 0.06463800461802705
# {'weights': 'distance', 'n_neighbors': 236} gives r2_score: 0.15841709460680786
# {'weights': 'uniform', 'n_neighbors': 241} gives r2_score: 0.06319393015334063
# {'weights': 'distance', 'n_neighbors': 241} gives r2_score: 0.15760713856014874
# {'weights': 'uniform', 'n_neighbors': 246} gives r2_score: 0.06420618557389968
# {'weights': 'distance', 'n_neighbors': 246} gives r2_score: 0.15798219233494504
# {'weights': 'uniform', 'n_neighbors': 251} gives r2_score: 0.0655663680348123
# {'weights': 'distance', 'n_neighbors': 251} gives r2_score: 0.1585857586135474
# {'weights': 'uniform', 'n_neighbors': 256} gives r2_score: 0.061615857319249456
# {'weights': 'distance', 'n_neighbors': 256} gives r2_score: 0.1566068413099474
# {'weights': 'uniform', 'n_neighbors': 261} gives r2_score: 0.057869376698159836
# {'weights': 'distance', 'n_neighbors': 261} gives r2_score: 0.15467446507884852
# {'weights': 'uniform', 'n_neighbors': 266} gives r2_score: 0.05361331747157794
# {'weights': 'distance', 'n_neighbors': 266} gives r2_score: 0.15290654423032057
# {'weights': 'uniform', 'n_neighbors': 271} gives r2_score: 0.05422188424012919
# {'weights': 'distance', 'n_neighbors': 271} gives r2_score: 0.15293441541908004
# {'weights': 'uniform', 'n_neighbors': 276} gives r2_score: 0.053127187336306836
# {'weights': 'distance', 'n_neighbors': 276} gives r2_score: 0.15237913511338963
# {'weights': 'uniform', 'n_neighbors': 281} gives r2_score: 0.05380363152192036
# {'weights': 'distance', 'n_neighbors': 281} gives r2_score: 0.15220163300519673
# {'weights': 'uniform', 'n_neighbors': 286} gives r2_score: 0.05538761527170566
# {'weights': 'distance', 'n_neighbors': 286} gives r2_score: 0.15244417950334144
# {'weights': 'uniform', 'n_neighbors': 291} gives r2_score: 0.05540962075021871
# {'weights': 'distance', 'n_neighbors': 291} gives r2_score: 0.15210880402452776
# {'weights': 'uniform', 'n_neighbors': 296} gives r2_score: 0.05470704914158364
# {'weights': 'distance', 'n_neighbors': 296} gives r2_score: 0.15149873527454882
# {'weights': 'uniform', 'n_neighbors': 301} gives r2_score: 0.058418002009960834
# {'weights': 'distance', 'n_neighbors': 301} gives r2_score: 0.15217033045328
# {'weights': 'uniform', 'n_neighbors': 306} gives r2_score: 0.06021820893977636
# {'weights': 'distance', 'n_neighbors': 306} gives r2_score: 0.15251142797283812
# {'weights': 'uniform', 'n_neighbors': 311} gives r2_score: 0.05927357607229655
# {'weights': 'distance', 'n_neighbors': 311} gives r2_score: 0.152475836021443
# {'weights': 'uniform', 'n_neighbors': 316} gives r2_score: 0.06154471161198227
# {'weights': 'distance', 'n_neighbors': 316} gives r2_score: 0.15293175149782157
# {'weights': 'uniform', 'n_neighbors': 321} gives r2_score: 0.061315832072718734
# {'weights': 'distance', 'n_neighbors': 321} gives r2_score: 0.15342408478281544
# {'weights': 'uniform', 'n_neighbors': 326} gives r2_score: 0.05675755590751619
# {'weights': 'distance', 'n_neighbors': 326} gives r2_score: 0.1533371596536851
# {'weights': 'uniform', 'n_neighbors': 331} gives r2_score: 0.054906946869996864
# {'weights': 'distance', 'n_neighbors': 331} gives r2_score: 0.15325204856600383
# {'weights': 'uniform', 'n_neighbors': 336} gives r2_score: 0.05145186793364198
# {'weights': 'distance', 'n_neighbors': 336} gives r2_score: 0.15321801571201432
# {'weights': 'uniform', 'n_neighbors': 341} gives r2_score: 0.04807956193208629
# {'weights': 'distance', 'n_neighbors': 341} gives r2_score: 0.15313782381183416
# {'weights': 'uniform', 'n_neighbors': 346} gives r2_score: 0.043811258223063976
# {'weights': 'distance', 'n_neighbors': 346} gives r2_score: 0.15308414506195056
# {'weights': 'uniform', 'n_neighbors': 351} gives r2_score: 0.041361791971218254
# {'weights': 'distance', 'n_neighbors': 351} gives r2_score: 0.15285283597317623
# {'weights': 'uniform', 'n_neighbors': 356} gives r2_score: 0.037706532642882595
# {'weights': 'distance', 'n_neighbors': 356} gives r2_score: 0.15283503351433192
# {'weights': 'uniform', 'n_neighbors': 361} gives r2_score: 0.03486748942527218
# {'weights': 'distance', 'n_neighbors': 361} gives r2_score: 0.1526140142117055
# {'weights': 'uniform', 'n_neighbors': 366} gives r2_score: 0.03292108061373755
# {'weights': 'distance', 'n_neighbors': 366} gives r2_score: 0.15244032334885516
# {'weights': 'uniform', 'n_neighbors': 371} gives r2_score: 0.030750653927246963
# {'weights': 'distance', 'n_neighbors': 371} gives r2_score: 0.15255141706823394
# {'weights': 'uniform', 'n_neighbors': 376} gives r2_score: 0.028466229326580827
# {'weights': 'distance', 'n_neighbors': 376} gives r2_score: 0.1527395470072922
# {'weights': 'uniform', 'n_neighbors': 381} gives r2_score: 0.023613302735574826
# {'weights': 'distance', 'n_neighbors': 381} gives r2_score: 0.15323611429417938
# {'weights': 'uniform', 'n_neighbors': 386} gives r2_score: 0.016319207309407835
# {'weights': 'distance', 'n_neighbors': 386} gives r2_score: 0.15333844658989748
# {'weights': 'uniform', 'n_neighbors': 391} gives r2_score: 0.011125721090285312
# {'weights': 'distance', 'n_neighbors': 391} gives r2_score: 0.15389545622164402
# {'weights': 'uniform', 'n_neighbors': 396} gives r2_score: 0.006683752603466875
# {'weights': 'distance', 'n_neighbors': 396} gives r2_score: 0.15439468685676416
# {'weights': 'uniform', 'n_neighbors': 401} gives r2_score: 0.0020488951007211487
# {'weights': 'distance', 'n_neighbors': 401} gives r2_score: 0.15432047369705693
# {'alpha': 0.01} gives r2_score: 0.5890783587547592
# {'alpha': 0.02} gives r2_score: 0.5889556230334261
# {'alpha': 0.03} gives r2_score: 0.5888329958198372
# {'alpha': 0.04} gives r2_score: 0.5887105246444941
# {'alpha': 0.05} gives r2_score: 0.5885882537284242
# {'alpha': 0.06} gives r2_score: 0.5884662241932571
# {'alpha': 0.07} gives r2_score: 0.5883444742572626
# {'alpha': 0.08} gives r2_score: 0.588223039418365
# {'alpha': 0.09} gives r2_score: 0.5881019526250715
# {'alpha': 0.1} gives r2_score: 0.5879812444361775
# {'alpha': 0.11} gives r2_score: 0.5878609431700399
# {'alpha': 0.12} gives r2_score: 0.5877410750441605
# {'alpha': 0.13} gives r2_score: 0.5876216643057519
# {'alpha': 0.14} gives r2_score: 0.5875027333539153
# {'alpha': 0.15} gives r2_score: 0.5873843028540096
# {'alpha': 0.16} gives r2_score: 0.5872663918447467
# {'alpha': 0.17} gives r2_score: 0.5871490178385128
# {'alpha': 0.18} gives r2_score: 0.5870321969153702
# {'alpha': 0.19} gives r2_score: 0.5869159438111705
# {'alpha': 0.2} gives r2_score: 0.5868002720001703
# {'alpha': 0.21} gives r2_score: 0.5866851937725179
# {'alpha': 0.22} gives r2_score: 0.586570720306951
# {'alpha': 0.23} gives r2_score: 0.5864568617390167
# {'alpha': 0.24} gives r2_score: 0.5863436272251155
# {'alpha': 0.25} gives r2_score: 0.5862310250026304
# {'alpha': 0.26} gives r2_score: 0.5861190624464065
# {'alpha': 0.27} gives r2_score: 0.5860077461218048
# {'alpha': 0.28} gives r2_score: 0.5858970818345589
# {'alpha': 0.29} gives r2_score: 0.5857870746776355
# {'alpha': 0.3} gives r2_score: 0.5856777290752833
# {'alpha': 0.31} gives r2_score: 0.5855690488244585
# {'alpha': 0.32} gives r2_score: 0.5854610371337823
# {'alpha': 0.33} gives r2_score: 0.585353696660188
# {'alpha': 0.34} gives r2_score: 0.5852470295434041
# {'alpha': 0.35000000000000003} gives r2_score: 0.5851410374384005
# {'alpha': 0.36} gives r2_score: 0.5850357215459316
# {'alpha': 0.37} gives r2_score: 0.5849310826412866
# {'alpha': 0.38} gives r2_score: 0.5848271211013583
# {'alpha': 0.39} gives r2_score: 0.584723836930134
# {'alpha': 0.4} gives r2_score: 0.5846212297827016
# {'alpha': 0.41000000000000003} gives r2_score: 0.5845192989878638
# {'alpha': 0.42} gives r2_score: 0.5844180435694388
# {'alpha': 0.43} gives r2_score: 0.5843174622663303
# {'alpha': 0.44} gives r2_score: 0.5842175535514388
# {'alpha': 0.45} gives r2_score: 0.5841183156494817
# {'alpha': 0.46} gives r2_score: 0.5840197465537866
# {'alpha': 0.47000000000000003} gives r2_score: 0.5839218440421214
# {'alpha': 0.48} gives r2_score: 0.5838246056916134
# {'alpha': 0.49} gives r2_score: 0.5837280288928113
# {'alpha': 0.5} gives r2_score: 0.5836321108629443
# {'alpha': 0.51} gives r2_score: 0.5835368486584162
# {'alpha': 0.52} gives r2_score: 0.5834422391865899
# {'alpha': 0.53} gives r2_score: 0.583348279216892
# {'alpha': 0.54} gives r2_score: 0.5832549653912849
# {'alpha': 0.55} gives r2_score: 0.5831622942341353
# {'alpha': 0.56} gives r2_score: 0.5830702621615227
# {'alpha': 0.5700000000000001} gives r2_score: 0.5829788654900097
# {'alpha': 0.58} gives r2_score: 0.5828881004449109
# {'alpha': 0.59} gives r2_score: 0.5827979631680884
# {'alpha': 0.6} gives r2_score: 0.5827084497252957
# {'alpha': 0.61} gives r2_score: 0.5826195561131027
# {'alpha': 0.62} gives r2_score: 0.5825312782654188
# {'alpha': 0.63} gives r2_score: 0.5824436120596392
# {'alpha': 0.64} gives r2_score: 0.5823565533224382
# {'alpha': 0.65} gives r2_score: 0.5822700978352207
# {'alpha': 0.66} gives r2_score: 0.5821842413392626
# {'alpha': 0.67} gives r2_score: 0.5820989795405467
# {'alpha': 0.68} gives r2_score: 0.582014308114317
# {'alpha': 0.6900000000000001} gives r2_score: 0.5819302227093652
# {'alpha': 0.7000000000000001} gives r2_score: 0.5818467189520635
# {'alpha': 0.71} gives r2_score: 0.5817637924501593
# {'alpha': 0.72} gives r2_score: 0.581681438796342
# {'alpha': 0.73} gives r2_score: 0.5815996535715997
# {'alpha': 0.74} gives r2_score: 0.5815184323483691
# {'alpha': 0.75} gives r2_score: 0.5814377706934983
# {'alpha': 0.76} gives r2_score: 0.5813576641710272
# {'alpha': 0.77} gives r2_score: 0.5812781083447982
# {'alpha': 0.78} gives r2_score: 0.5811990987809044
# {'alpha': 0.79} gives r2_score: 0.5811206310499857
# {'alpha': 0.8} gives r2_score: 0.581042700729381
# {'alpha': 0.81} gives r2_score: 0.5809653034051427
# {'alpha': 0.8200000000000001} gives r2_score: 0.5808884346739227
# {'alpha': 0.8300000000000001} gives r2_score: 0.5808120901447366
# {'alpha': 0.84} gives r2_score: 0.5807362654406125
# {'alpha': 0.85} gives r2_score: 0.5806609562001297
# {'alpha': 0.86} gives r2_score: 0.5805861580788534
# {'alpha': 0.87} gives r2_score: 0.5805118667506752
# {'alpha': 0.88} gives r2_score: 0.5804380779090568
# {'alpha': 0.89} gives r2_score: 0.5803647872681887
# {'alpha': 0.9} gives r2_score: 0.5802919905640664
# {'alpha': 0.91} gives r2_score: 0.5802196835554876
# {'alpha': 0.92} gives r2_score: 0.5801478620249749
# {'alpha': 0.93} gives r2_score: 0.5800765217796309
# {'alpha': 0.9400000000000001} gives r2_score: 0.5800056586519244
# {'alpha': 0.9500000000000001} gives r2_score: 0.5799352685004171
# {'alpha': 0.96} gives r2_score: 0.5798653472104278
# {'alpha': 0.97} gives r2_score: 0.5797958906946441
# {'alpha': 0.98} gives r2_score: 0.5797268948936798
# {'alpha': 0.99} gives r2_score: 0.579658355776582
# Best Hyperparameters for KNearest: {'weights': 'distance', 'n_neighbors': 6} with r2_score: 0.39913612195781145
# Best Hyperparameters for Ridge Regression: {'alpha': 0.01} with r2_score: 0.5890783587547592

# %% [markdown]
# # Now Test your own Hyperparameter Tuner for the algorithm you've created
