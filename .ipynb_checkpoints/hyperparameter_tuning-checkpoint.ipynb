# %% [markdown]
# # Tuning The Hyperparameters  - Using A Naive Pythonic Approach

# %% [markdown]
# We will be using the boston dataset for the examples and the exercises.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge 
from sklearn.datasets import load_boston
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# We'll be using a train-test split of 80:20 for training and validation of the algorithm

# %%
X,y = load_boston(return_X_y=True)
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Lets have our own Simple Hyperparameter Tuner !!

# %%
def custom_hyperparameter_tuner( hyperparams_dict , algorithm , metric_score="score" ):
    
    """
    Implementation of a Simple Loop Based 
    Hyperparameter Tuning based on the metric score, , 
    hyperparameter combinations and algorithms provided as arguments
    """
    
    if metric_score=="score":
        
        """
        Based on the r2_score , it selects out the best hyperparameter out of all the hyperparameters 
        """
        
        best_hyperparams=None
        best_accuracy=-99999
        
        if algorithm=="Ridge":
            for i in hyperparams_dict:
                ridge = Ridge(alpha = i['alpha'])
                ridge.fit(x_train,y_train)
                y_pred = ridge.predict(x_test)
                score = ridge.score(x_test, y_test)
                print("Hyperparameter:",i)
                print("Accuracy:",score)
                print("\n====================================\n")
                if score > best_accuracy:
                    best_accuracy=score
                    best_hyperparams=i
                    
        
        if algorithm=="KNearest":
            for i in hyperparams_dict:
                knearest=KNeighborsRegressor(n_neighbors=i['n_neighbors'],weights=i['weights'])
                knearest.fit(x_train,y_train)
                y_pred = knearest.predict(x_test)
                score = knearest.score(x_test , y_test)
                print("Hyperparameter:",i)
                print("Accuracy:",score)
                print("\n====================================\n")
                if score > best_accuracy:
                    best_accuracy=score
                    best_hyperparams=i
            
            
#         if algorithm=="SVM Regressor":
#         """
#             1. Create a SVM Regressor for each of the choice sets in the hyperparams_dict
#             2. Fit it on X_train and predict on X_test 
#             3. Calculate r2_score and find the best hyperparams
#         """
        
    return best_hyperparams

# %% [markdown]
# Create the Hyperparameter Combinations by using loops

# %%
def create_hyperparameter_dict( algorithm ):
    hyperparams_dict=[]
    if algorithm=="Ridge":
        """
        For Ridge , We have taken only one hyperparameter(alpha)'s hyperparameters .
        alpha: can be any value b/w 0 and 1
        """
        for i in range(1,1000):
            hyperparams_dict.append({"alpha":i*0.01})
            i+=1
    
    if algorithm=="KNearest":
        """
        For KNearest Regressor , We have taken n_neighbors and weights as the hyperparameters
        n_neighbors: can have any integral value b/w 1 to no_of_samples
        weights: can be any one out of {"uniform","distance"}
        """
        weights=["uniform","distance"]
        for i in range(1,x_train.shape[0],5):
            for j in range(0,2,1):
                hyperparams_dict.append({"n_neighbors":i,"weights":weights[j]})


#     if algorithm=="SVMRegressor":
#         """
#         For SVM Regressor , take kernel , C(penality parameter) , max_iter  as the hyperparameters
#         kernel: can be any one out of {"linear","poly","rbf","sigmoid"}
#         C: can be any value b/w 0 and 1 
#         max_iter: can be b/w (1,100)
#         """
            
    
    return hyperparams_dict

# %% [markdown]
# # We have our Hyperparameter Tuner !! Lets Test it

# %%
#create the search space
hyperparams_dict=create_hyperparameter_dict("KNearest")  

#tune the hyper-params on space
best_hyperparams=custom_hyperparameter_tuner(hyperparams_dict,"KNearest","r2_score") 

print("Best Hyperparameters for Ridge Regression: "+str(best_hyperparams2))
# Out:
# ('Hyperparameter:', {'n_neighbors': 1, 'weights': 'uniform'})
# ('Accuracy:', 0.2702325598524651)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 1, 'weights': 'distance'})
# ('Accuracy:', 0.2702325598524651)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 6, 'weights': 'uniform'})
# ('Accuracy:', 0.35917334579441773)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 6, 'weights': 'distance'})
# ('Accuracy:', 0.39913612195781145)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 11, 'weights': 'uniform'})
# ('Accuracy:', 0.3316851639617685)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 11, 'weights': 'distance'})
# ('Accuracy:', 0.3846740822593764)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 16, 'weights': 'uniform'})
# ('Accuracy:', 0.26048258297177385)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 16, 'weights': 'distance'})
# ('Accuracy:', 0.3383782837657625)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 21, 'weights': 'uniform'})
# ('Accuracy:', 0.21597922416282078)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 21, 'weights': 'distance'})
# ('Accuracy:', 0.30630206590040643)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 26, 'weights': 'uniform'})
# ('Accuracy:', 0.18560891557593617)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 26, 'weights': 'distance'})
# ('Accuracy:', 0.2817312200671872)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 31, 'weights': 'uniform'})
# ('Accuracy:', 0.1560405066297178)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 31, 'weights': 'distance'})
# ('Accuracy:', 0.2591542191711972)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 36, 'weights': 'uniform'})
# ('Accuracy:', 0.11815103293386964)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 36, 'weights': 'distance'})
# ('Accuracy:', 0.22940574886134601)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 41, 'weights': 'uniform'})
# ('Accuracy:', 0.09279037624947273)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 41, 'weights': 'distance'})
# ('Accuracy:', 0.2091178295604078)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 46, 'weights': 'uniform'})
# ('Accuracy:', 0.08319976783252536)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 46, 'weights': 'distance'})
# ('Accuracy:', 0.19943424850196723)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 51, 'weights': 'uniform'})
# ('Accuracy:', 0.06831579333150772)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 51, 'weights': 'distance'})
# ('Accuracy:', 0.18783354719541023)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 56, 'weights': 'uniform'})
# ('Accuracy:', 0.0683265544598689)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 56, 'weights': 'distance'})
# ('Accuracy:', 0.1848271709528373)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 61, 'weights': 'uniform'})
# ('Accuracy:', 0.06127967951264135)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 61, 'weights': 'distance'})
# ('Accuracy:', 0.17940754642223555)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 66, 'weights': 'uniform'})
# ('Accuracy:', 0.059100164425029966)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 66, 'weights': 'distance'})
# ('Accuracy:', 0.17488021750570126)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 71, 'weights': 'uniform'})
# ('Accuracy:', 0.058817067019603986)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 71, 'weights': 'distance'})
# ('Accuracy:', 0.1720885112038648)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 76, 'weights': 'uniform'})
# ('Accuracy:', 0.05578729393820925)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 76, 'weights': 'distance'})
# ('Accuracy:', 0.16873469049132106)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 81, 'weights': 'uniform'})
# ('Accuracy:', 0.05688878336364711)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 81, 'weights': 'distance'})
# ('Accuracy:', 0.16844758463762222)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 86, 'weights': 'uniform'})
# ('Accuracy:', 0.061033914258595834)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 86, 'weights': 'distance'})
# ('Accuracy:', 0.16814274609586854)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 91, 'weights': 'uniform'})
# ('Accuracy:', 0.06669230306072405)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 91, 'weights': 'distance'})
# ('Accuracy:', 0.16886232067609497)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 96, 'weights': 'uniform'})
# ('Accuracy:', 0.07105232872324863)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 96, 'weights': 'distance'})
# ('Accuracy:', 0.169630909399743)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 101, 'weights': 'uniform'})
# ('Accuracy:', 0.08213931997392065)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 101, 'weights': 'distance'})
# ('Accuracy:', 0.172869066523599)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 106, 'weights': 'uniform'})
# ('Accuracy:', 0.08412778912112262)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 106, 'weights': 'distance'})
# ('Accuracy:', 0.17309164324446458)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 111, 'weights': 'uniform'})
# ('Accuracy:', 0.0908752668587639)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 111, 'weights': 'distance'})
# ('Accuracy:', 0.17293266119720851)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 116, 'weights': 'uniform'})
# ('Accuracy:', 0.08986617634154415)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 116, 'weights': 'distance'})
# ('Accuracy:', 0.1731711092461683)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 121, 'weights': 'uniform'})
# ('Accuracy:', 0.0944439170599779)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 121, 'weights': 'distance'})
# ('Accuracy:', 0.17387256568688825)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 126, 'weights': 'uniform'})
# ('Accuracy:', 0.0947972452568947)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 126, 'weights': 'distance'})
# ('Accuracy:', 0.17286090188143255)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 131, 'weights': 'uniform'})
# ('Accuracy:', 0.09498474322930806)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 131, 'weights': 'distance'})
# ('Accuracy:', 0.1726345829274467)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 136, 'weights': 'uniform'})
# ('Accuracy:', 0.08961369476012016)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 136, 'weights': 'distance'})
# ('Accuracy:', 0.17124588052292555)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 141, 'weights': 'uniform'})
# ('Accuracy:', 0.08991142481771275)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 141, 'weights': 'distance'})
# ('Accuracy:', 0.17020735451435598)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 146, 'weights': 'uniform'})
# ('Accuracy:', 0.08993765976588686)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 146, 'weights': 'distance'})
# ('Accuracy:', 0.16952080246644685)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 151, 'weights': 'uniform'})
# ('Accuracy:', 0.08806089361252512)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 151, 'weights': 'distance'})
# ('Accuracy:', 0.16896356322893313)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 156, 'weights': 'uniform'})
# ('Accuracy:', 0.08704238815911414)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 156, 'weights': 'distance'})
# ('Accuracy:', 0.16840324873761792)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 161, 'weights': 'uniform'})
# ('Accuracy:', 0.08564373925899815)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 161, 'weights': 'distance'})
# ('Accuracy:', 0.1672191106382107)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 166, 'weights': 'uniform'})
# ('Accuracy:', 0.08130536317275361)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 166, 'weights': 'distance'})
# ('Accuracy:', 0.16588290723976729)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 171, 'weights': 'uniform'})
# ('Accuracy:', 0.07724332862887784)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 171, 'weights': 'distance'})
# ('Accuracy:', 0.16438570454345902)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 176, 'weights': 'uniform'})
# ('Accuracy:', 0.07571466231282376)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 176, 'weights': 'distance'})
# ('Accuracy:', 0.1638143816332931)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 181, 'weights': 'uniform'})
# ('Accuracy:', 0.07633431544560543)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 181, 'weights': 'distance'})
# ('Accuracy:', 0.1639366622783457)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 186, 'weights': 'uniform'})
# ('Accuracy:', 0.07542350074737347)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 186, 'weights': 'distance'})
# ('Accuracy:', 0.16347788295817622)
#
# ====================================
# ('Hyperparameter:', {'n_neighbors': 191, 'weights': 'uniform'})
# ('Accuracy:', 0.07675578440428132)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 191, 'weights': 'distance'})
# ('Accuracy:', 0.16378041997465165)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 196, 'weights': 'uniform'})
# ('Accuracy:', 0.08129133183209147)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 196, 'weights': 'distance'})
# ('Accuracy:', 0.16460259317457226)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 201, 'weights': 'uniform'})
# ('Accuracy:', 0.0785936763371462)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 201, 'weights': 'distance'})
# ('Accuracy:', 0.1633321496714778)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 206, 'weights': 'uniform'})
# ('Accuracy:', 0.0722201799471025)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 206, 'weights': 'distance'})
# ('Accuracy:', 0.16136631032887672)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 211, 'weights': 'uniform'})
# ('Accuracy:', 0.06707738716446177)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 211, 'weights': 'distance'})
# ('Accuracy:', 0.15960275779025224)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 216, 'weights': 'uniform'})
# ('Accuracy:', 0.06677764080235027)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 216, 'weights': 'distance'})
# ('Accuracy:', 0.15953461417566062)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 221, 'weights': 'uniform'})
# ('Accuracy:', 0.06511118334864918)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 221, 'weights': 'distance'})
# ('Accuracy:', 0.15865670206857252)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 226, 'weights': 'uniform'})
# ('Accuracy:', 0.06448013604629665)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 226, 'weights': 'distance'})
# ('Accuracy:', 0.15834645621089893)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 231, 'weights': 'uniform'})
# ('Accuracy:', 0.06468415414864948)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 231, 'weights': 'distance'})
# ('Accuracy:', 0.15853843758692865)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 236, 'weights': 'uniform'})
# ('Accuracy:', 0.06463800461802705)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 236, 'weights': 'distance'})
# ('Accuracy:', 0.1584170946068053)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 241, 'weights': 'uniform'})
# ('Accuracy:', 0.06319393015334063)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 241, 'weights': 'distance'})
# ('Accuracy:', 0.15760713856014608)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 246, 'weights': 'uniform'})
# ('Accuracy:', 0.06420618557389968)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 246, 'weights': 'distance'})
# ('Accuracy:', 0.15798219233494226)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 251, 'weights': 'uniform'})
# ('Accuracy:', 0.0655663680348123)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 251, 'weights': 'distance'})
# ('Accuracy:', 0.15858575861354451)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 256, 'weights': 'uniform'})
# ('Accuracy:', 0.061615857319249456)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 256, 'weights': 'distance'})
# ('Accuracy:', 0.1566068413099445)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 261, 'weights': 'uniform'})
# ('Accuracy:', 0.057869376698159836)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 261, 'weights': 'distance'})
# ('Accuracy:', 0.15467446507884552)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 266, 'weights': 'uniform'})
# ('Accuracy:', 0.05361331747157794)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 266, 'weights': 'distance'})
# ('Accuracy:', 0.1529065442303177)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 271, 'weights': 'uniform'})
# ('Accuracy:', 0.05422188424012919)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 271, 'weights': 'distance'})
# ('Accuracy:', 0.15293441541907704)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 276, 'weights': 'uniform'})
# ('Accuracy:', 0.053127187336306836)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 276, 'weights': 'distance'})
# ('Accuracy:', 0.15237913511338685)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 281, 'weights': 'uniform'})
# ('Accuracy:', 0.05380363152192036)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 281, 'weights': 'distance'})
# ('Accuracy:', 0.15220163300519363)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 286, 'weights': 'uniform'})
# ('Accuracy:', 0.05538761527170566)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 286, 'weights': 'distance'})
# ('Accuracy:', 0.15244417950333833)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 291, 'weights': 'uniform'})
# ('Accuracy:', 0.05540962075021871)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 291, 'weights': 'distance'})
# ('Accuracy:', 0.15210880402452454)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 296, 'weights': 'uniform'})
# ('Accuracy:', 0.05470704914158364)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 296, 'weights': 'distance'})
# ('Accuracy:', 0.15149873527454583)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 301, 'weights': 'uniform'})
# ('Accuracy:', 0.058418002009960834)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 301, 'weights': 'distance'})
# ('Accuracy:', 0.15217033045327677)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 306, 'weights': 'uniform'})
# ('Accuracy:', 0.06021820893977636)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 306, 'weights': 'distance'})
# ('Accuracy:', 0.1525114279728349)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 311, 'weights': 'uniform'})
# ('Accuracy:', 0.05927357607229655)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 311, 'weights': 'distance'})
# ('Accuracy:', 0.15247583602143966)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 316, 'weights': 'uniform'})
# ('Accuracy:', 0.06154471161198227)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 316, 'weights': 'distance'})
# ('Accuracy:', 0.15293175149781824)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 321, 'weights': 'uniform'})
# ('Accuracy:', 0.061315832072718734)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 321, 'weights': 'distance'})
# ('Accuracy:', 0.153424084782812)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 326, 'weights': 'uniform'})
# ('Accuracy:', 0.05675755590751619)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 326, 'weights': 'distance'})
# ('Accuracy:', 0.15333715965368133)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 331, 'weights': 'uniform'})
# ('Accuracy:', 0.054906946869996864)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 331, 'weights': 'distance'})
# ('Accuracy:', 0.15325204856599994)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 336, 'weights': 'uniform'})
# ('Accuracy:', 0.05145186793364198)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 336, 'weights': 'distance'})
# ('Accuracy:', 0.15321801571201032)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 341, 'weights': 'uniform'})
# ('Accuracy:', 0.04807956193208629)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 341, 'weights': 'distance'})
# ('Accuracy:', 0.15313782381183005)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 346, 'weights': 'uniform'})
# ('Accuracy:', 0.043811258223063976)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 346, 'weights': 'distance'})
# ('Accuracy:', 0.15308414506194656)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 351, 'weights': 'uniform'})
# ('Accuracy:', 0.041361791971218254)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 351, 'weights': 'distance'})
# ('Accuracy:', 0.152852835973172)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 356, 'weights': 'uniform'})
# ('Accuracy:', 0.037706532642882595)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 356, 'weights': 'distance'})
# ('Accuracy:', 0.1528350335143276)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 361, 'weights': 'uniform'})
# ('Accuracy:', 0.03486748942527218)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 361, 'weights': 'distance'})
# ('Accuracy:', 0.15261401421170118)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 366, 'weights': 'uniform'})
# ('Accuracy:', 0.03292108061373755)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 366, 'weights': 'distance'})
# ('Accuracy:', 0.15244032334885071)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 371, 'weights': 'uniform'})
# ('Accuracy:', 0.030750653927246963)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 371, 'weights': 'distance'})
# ('Accuracy:', 0.15255141706822972)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 376, 'weights': 'uniform'})
# ('Accuracy:', 0.028466229326580827)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 376, 'weights': 'distance'})
# ('Accuracy:', 0.15273954700728776)
#
# ====================================
# ('Hyperparameter:', {'n_neighbors': 381, 'weights': 'uniform'})
# ('Accuracy:', 0.023613302735574826)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 381, 'weights': 'distance'})
# ('Accuracy:', 0.15323611429417483)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 386, 'weights': 'uniform'})
# ('Accuracy:', 0.016319207309407835)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 386, 'weights': 'distance'})
# ('Accuracy:', 0.15333844658989282)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 391, 'weights': 'uniform'})
# ('Accuracy:', 0.011125721090285312)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 391, 'weights': 'distance'})
# ('Accuracy:', 0.15389545622163914)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 396, 'weights': 'uniform'})
# ('Accuracy:', 0.006683752603466875)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 396, 'weights': 'distance'})
# ('Accuracy:', 0.15439468685675917)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 401, 'weights': 'uniform'})
# ('Accuracy:', 0.0020488951007211487)
#
# ====================================
#
# ('Hyperparameter:', {'n_neighbors': 401, 'weights': 'distance'})
# ('Accuracy:', 0.15432047369705193)
#
# ====================================
#
# Best Hyperparameters for Ridge Regression: {'alpha': 1}

# %%
#create the search space
hyperparams_dict2=create_hyperparameter_dict("Ridge")

#create the search space
best_hyperparams2=custom_hyperparameter_tuner(hyperparams_dict2,"Ridge","r2_score")

print("Best Hyperparameters for KNearest: " +str(best_hyperparams))
# Out:
# ('Hyperparameter:', {'alpha': 0.01})
# ('Accuracy:', 0.589078358754759)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.02})
# ('Accuracy:', 0.5889556230334259)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.03})
# ('Accuracy:', 0.5888329958198371)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.04})
# ('Accuracy:', 0.5887105246444938)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.05})
# ('Accuracy:', 0.5885882537284242)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.06})
# ('Accuracy:', 0.588466224193257)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.07})
# ('Accuracy:', 0.5883444742572626)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.08})
# ('Accuracy:', 0.588223039418365)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.09})
# ('Accuracy:', 0.5881019526250716)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.1})
# ('Accuracy:', 0.5879812444361775)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.11})
# ('Accuracy:', 0.5878609431700399)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.12})
# ('Accuracy:', 0.5877410750441604)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.13})
# ('Accuracy:', 0.5876216643057517)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.14})
# ('Accuracy:', 0.5875027333539153)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.15})
# ('Accuracy:', 0.5873843028540094)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.16})
# ('Accuracy:', 0.5872663918447465)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.17})
# ('Accuracy:', 0.5871490178385126)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.18})
# ('Accuracy:', 0.5870321969153702)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.19})
# ('Accuracy:', 0.5869159438111704)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.2})
# ('Accuracy:', 0.5868002720001702)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.21})
# ('Accuracy:', 0.586685193772518)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.22})
# ('Accuracy:', 0.5865707203069508)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.23})
# ('Accuracy:', 0.5864568617390168)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.24})
# ('Accuracy:', 0.5863436272251152)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.25})
# ('Accuracy:', 0.5862310250026305)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.26})
# ('Accuracy:', 0.5861190624464064)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.27})
# ('Accuracy:', 0.5860077461218045)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.28})
# ('Accuracy:', 0.5858970818345589)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.29})
# ('Accuracy:', 0.5857870746776355)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.3})
# ('Accuracy:', 0.5856777290752833)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.31})
# ('Accuracy:', 0.5855690488244586)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.32})
# ('Accuracy:', 0.5854610371337821)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.33})
# ('Accuracy:', 0.585353696660188)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.34})
# ('Accuracy:', 0.5852470295434038)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.35000000000000003})
# ('Accuracy:', 0.5851410374384002)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.36})
# ('Accuracy:', 0.5850357215459315)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.37})
# ('Accuracy:', 0.5849310826412866)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.38})
# ('Accuracy:', 0.5848271211013583)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.39})
# ('Accuracy:', 0.5847238369301337)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.4})
# ('Accuracy:', 0.5846212297827014)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.41000000000000003})
# ('Accuracy:', 0.5845192989878636)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.42})
# ('Accuracy:', 0.5844180435694387)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.43})
# ('Accuracy:', 0.5843174622663303)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.44})
# ('Accuracy:', 0.584217553551439)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.45})
# ('Accuracy:', 0.5841183156494816)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.46})
# ('Accuracy:', 0.5840197465537864)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.47000000000000003})
# ('Accuracy:', 0.5839218440421212)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.48})
# ('Accuracy:', 0.5838246056916132)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.49})
# ('Accuracy:', 0.5837280288928113)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.5})
# ('Accuracy:', 0.5836321108629441)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.51})
# ('Accuracy:', 0.583536848658416)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.52})
# ('Accuracy:', 0.5834422391865899)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.53})
# ('Accuracy:', 0.5833482792168923)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.54})
# ('Accuracy:', 0.5832549653912846)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.55})
# ('Accuracy:', 0.5831622942341352)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.56})
# ('Accuracy:', 0.5830702621615227)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.5700000000000001})
# ('Accuracy:', 0.5829788654900094)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.58})
# ('Accuracy:', 0.5828881004449109)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.59})
# ('Accuracy:', 0.5827979631680884)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.6})
# ('Accuracy:', 0.582708449725296)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.61})
# ('Accuracy:', 0.5826195561131027)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.62})
# ('Accuracy:', 0.5825312782654186)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.63})
# ('Accuracy:', 0.5824436120596392)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.64})
# ('Accuracy:', 0.582356553322438)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.65})
# ('Accuracy:', 0.5822700978352205)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.66})
# ('Accuracy:', 0.5821842413392624)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.67})
# ('Accuracy:', 0.5820989795405466)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.68})
# ('Accuracy:', 0.5820143081143169)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.6900000000000001})
# ('Accuracy:', 0.5819302227093652)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.7000000000000001})
# ('Accuracy:', 0.5818467189520635)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.71})
# ('Accuracy:', 0.5817637924501591)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.72})
# ('Accuracy:', 0.5816814387963422)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.73})
# ('Accuracy:', 0.5815996535715997)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.74})
# ('Accuracy:', 0.5815184323483692)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.75})
# ('Accuracy:', 0.5814377706934981)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.76})
# ('Accuracy:', 0.5813576641710271)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.77})
# ('Accuracy:', 0.5812781083447982)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.78})
# ('Accuracy:', 0.5811990987809043)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.79})
# ('Accuracy:', 0.5811206310499855)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.8})
# ('Accuracy:', 0.581042700729381)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.81})
# ('Accuracy:', 0.5809653034051425)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.8200000000000001})
# ('Accuracy:', 0.5808884346739225)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.8300000000000001})
# ('Accuracy:', 0.5808120901447363)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.84})
# ('Accuracy:', 0.5807362654406125)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.85})
# ('Accuracy:', 0.5806609562001296)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.86})
# ('Accuracy:', 0.5805861580788535)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.87})
# ('Accuracy:', 0.5805118667506753)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.88})
# ('Accuracy:', 0.5804380779090568)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.89})
# ('Accuracy:', 0.5803647872681889)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.9})
# ('Accuracy:', 0.5802919905640664)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.91})
# ('Accuracy:', 0.5802196835554875)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.92})
# ('Accuracy:', 0.5801478620249749)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.93})
# ('Accuracy:', 0.5800765217796306)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.9400000000000001})
# ('Accuracy:', 0.5800056586519244)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.9500000000000001})
# ('Accuracy:', 0.579935268500417)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.96})
# ('Accuracy:', 0.5798653472104277)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.97})
# ('Accuracy:', 0.5797958906946441)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.98})
# ('Accuracy:', 0.5797268948936798)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 0.99})
# ('Accuracy:', 0.579658355776582)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.0})
# ('Accuracy:', 0.579590269341292)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.01})
# ('Accuracy:', 0.5795226316150619)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.02})
# ('Accuracy:', 0.5794554386548285)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.03})
# ('Accuracy:', 0.5793886865475473)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.04})
# ('Accuracy:', 0.5793223714104909)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.05})
# ('Accuracy:', 0.5792564893915101)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.06})
# ('Accuracy:', 0.5791910366692612)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.07})
# ('Accuracy:', 0.5791260094534058)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.08})
# ('Accuracy:', 0.5790614039847752)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.09})
# ('Accuracy:', 0.5789972165355118)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.1})
# ('Accuracy:', 0.5789334434091814)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.11})
# ('Accuracy:', 0.5788700809408618)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.12})
# ('Accuracy:', 0.5788071254972075)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.1300000000000001})
# ('Accuracy:', 0.5787445734764922)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.1400000000000001})
# ('Accuracy:', 0.5786824213086323)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.1500000000000001})
# ('Accuracy:', 0.578620665455189)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.16})
# ('Accuracy:', 0.5785593024093522)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.17})
# ('Accuracy:', 0.5784983286959083)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.18})
# ('Accuracy:', 0.5784377408711918)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.19})
# ('Accuracy:', 0.5783775355230212)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.2})
# ('Accuracy:', 0.5783177092706202)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.21})
# ('Accuracy:', 0.5782582587645277)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.22})
# ('Accuracy:', 0.5781991806864922)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.23})
# ('Accuracy:', 0.5781404717493583)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.24})
# ('Accuracy:', 0.5780821286969386)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.25})
# ('Accuracy:', 0.5780241483038786)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.26})
# ('Accuracy:', 0.5779665273755099)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.27})
# ('Accuracy:', 0.5779092627476963)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.28})
# ('Accuracy:', 0.5778523512866698)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.29})
# ('Accuracy:', 0.5777957898888613)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.3})
# ('Accuracy:', 0.5777395754807225)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.31})
# ('Accuracy:', 0.5776837050185419)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.32})
# ('Accuracy:', 0.5776281754882543)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.33})
# ('Accuracy:', 0.577572983905246)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.34})
# ('Accuracy:', 0.5775181273141532)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.35})
# ('Accuracy:', 0.5774636027886573)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.36})
# ('Accuracy:', 0.5774094074312743)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.37})
# ('Accuracy:', 0.5773555383731418)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.3800000000000001})
# ('Accuracy:', 0.5773019927738019)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.3900000000000001})
# ('Accuracy:', 0.5772487678209803)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.4000000000000001})
# ('Accuracy:', 0.5771958607303629)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.41})
# ('Accuracy:', 0.5771432687453707)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.42})
# ('Accuracy:', 0.5770909891369309)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.43})
# ('Accuracy:', 0.5770390192032466)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.44})
# ('Accuracy:', 0.5769873562695651)
#
# ====================================
# ('Hyperparameter:', {'alpha': 1.45})
# ('Accuracy:', 0.5769359976879446)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.46})
# ('Accuracy:', 0.5768849408370185)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.47})
# ('Accuracy:', 0.5768341831217599)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.48})
# ('Accuracy:', 0.5767837219732459)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.49})
# ('Accuracy:', 0.5767335548484174)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.5})
# ('Accuracy:', 0.5766836792298435)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.51})
# ('Accuracy:', 0.576634092625482)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.52})
# ('Accuracy:', 0.5765847925684414)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.53})
# ('Accuracy:', 0.5765357766167416)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.54})
# ('Accuracy:', 0.5764870423530755)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.55})
# ('Accuracy:', 0.5764385873845711)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.56})
# ('Accuracy:', 0.5763904093425538)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.57})
# ('Accuracy:', 0.5763425058823084)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.58})
# ('Accuracy:', 0.5762948746828427)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.59})
# ('Accuracy:', 0.5762475134466511)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.6})
# ('Accuracy:', 0.5762004198994799)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.61})
# ('Accuracy:', 0.576153591790092)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.62})
# ('Accuracy:', 0.5761070268900343)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.6300000000000001})
# ('Accuracy:', 0.5760607229934044)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.6400000000000001})
# ('Accuracy:', 0.5760146779166212)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.6500000000000001})
# ('Accuracy:', 0.5759688894981927)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.6600000000000001})
# ('Accuracy:', 0.5759233555984885)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.67})
# ('Accuracy:', 0.5758780740995117)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.68})
# ('Accuracy:', 0.575833042904674)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.69})
# ('Accuracy:', 0.5757882599385694)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.7})
# ('Accuracy:', 0.5757437231467524)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.71})
# ('Accuracy:', 0.5756994304955163)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.72})
# ('Accuracy:', 0.5756553799716717)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.73})
# ('Accuracy:', 0.5756115695823303)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.74})
# ('Accuracy:', 0.575567997354687)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.75})
# ('Accuracy:', 0.5755246613358038)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.76})
# ('Accuracy:', 0.5754815595923981)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.77})
# ('Accuracy:', 0.5754386902106299)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.78})
# ('Accuracy:', 0.5753960512958922)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.79})
# ('Accuracy:', 0.5753536409726029)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.8})
# ('Accuracy:', 0.5753114573839984)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.81})
# ('Accuracy:', 0.5752694986919282)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.82})
# ('Accuracy:', 0.575227763076654)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.83})
# ('Accuracy:', 0.5751862487366463)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.84})
# ('Accuracy:', 0.5751449538883869)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.85})
# ('Accuracy:', 0.5751038767661723)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.86})
# ('Accuracy:', 0.5750630156219154)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.87})
# ('Accuracy:', 0.5750223687249554)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.8800000000000001})
# ('Accuracy:', 0.5749819343618638)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.8900000000000001})
# ('Accuracy:', 0.5749417108362551)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.9000000000000001})
# ('Accuracy:', 0.5749016964685998)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.9100000000000001})
# ('Accuracy:', 0.5748618895960372)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.92})
# ('Accuracy:', 0.5748222885721912)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.93})
# ('Accuracy:', 0.5747828917669895)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.94})
# ('Accuracy:', 0.5747436975664808)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.95})
# ('Accuracy:', 0.5747047043726577)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.96})
# ('Accuracy:', 0.5746659106032805)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.97})
# ('Accuracy:', 0.5746273146917003)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.98})
# ('Accuracy:', 0.5745889150866876)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 1.99})
# ('Accuracy:', 0.5745507102522607)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.0})
# ('Accuracy:', 0.5745126986675158)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.0100000000000002})
# ('Accuracy:', 0.5744748788264604)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.02})
# ('Accuracy:', 0.574437249237846)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.0300000000000002})
# ('Accuracy:', 0.5743998084250064)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.04})
# ('Accuracy:', 0.5743625549256928)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.05})
# ('Accuracy:', 0.5743254872919165)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.06})
# ('Accuracy:', 0.574288604089787)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.07})
# ('Accuracy:', 0.5742519038993578)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.08})
# ('Accuracy:', 0.5742153853144705)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.09})
# ('Accuracy:', 0.5741790469426)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.1})
# ('Accuracy:', 0.5741428874047056)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.11})
# ('Accuracy:', 0.5741069053350787)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.12})
# ('Accuracy:', 0.5740710993811957)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.13})
# ('Accuracy:', 0.5740354682035708)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.14})
# ('Accuracy:', 0.5740000104756117)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.15})
# ('Accuracy:', 0.573964724883476)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.16})
# ('Accuracy:', 0.5739296101259304)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.17})
# ('Accuracy:', 0.5738946649142092)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.18})
# ('Accuracy:', 0.5738598879718771)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.19})
# ('Accuracy:', 0.5738252780346926)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.2})
# ('Accuracy:', 0.5737908338504718)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.21})
# ('Accuracy:', 0.5737565541789555)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.22})
# ('Accuracy:', 0.5737224377916775)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.23})
# ('Accuracy:', 0.5736884834718332)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.24})
# ('Accuracy:', 0.5736546900141511)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.25})
# ('Accuracy:', 0.5736210562247656)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.2600000000000002})
# ('Accuracy:', 0.5735875809210897)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.27})
# ('Accuracy:', 0.573554262931693)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.2800000000000002})
# ('Accuracy:', 0.5735211010961758)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.29})
# ('Accuracy:', 0.5734880942650491)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.3000000000000003})
# ('Accuracy:', 0.5734552412996152)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.31})
# ('Accuracy:', 0.5734225410718465)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.32})
# ('Accuracy:', 0.5733899924642704)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.33})
# ('Accuracy:', 0.5733575943698526)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.34})
# ('Accuracy:', 0.5733253456918816)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.35})
# ('Accuracy:', 0.5732932453438577)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.36})
# ('Accuracy:', 0.5732612922493787)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.37})
# ('Accuracy:', 0.5732294853420306)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.38})
# ('Accuracy:', 0.5731978235652786)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.39})
# ('Accuracy:', 0.5731663058723582)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.4})
# ('Accuracy:', 0.5731349312261698)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.41})
# ('Accuracy:', 0.573103698599172)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.42})
# ('Accuracy:', 0.5730726069732779)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.43})
# ('Accuracy:', 0.5730416553397533)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.44})
# ('Accuracy:', 0.5730108426991134)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.45})
# ('Accuracy:', 0.5729801680610234)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.46})
# ('Accuracy:', 0.572949630444199)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.47})
# ('Accuracy:', 0.5729192288763081)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.48})
# ('Accuracy:', 0.5728889623938741)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.49})
# ('Accuracy:', 0.5728588300421804)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.5})
# ('Accuracy:', 0.5728288308751754)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.5100000000000002})
# ('Accuracy:', 0.5727989639553794)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.52})
# ('Accuracy:', 0.572769228353792)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.5300000000000002})
# ('Accuracy:', 0.5727396231498009)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.54})
# ('Accuracy:', 0.5727101474310916)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.5500000000000003})
# ('Accuracy:', 0.572680800293559)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.56})
# ('Accuracy:', 0.5726515808412183)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.57})
# ('Accuracy:', 0.5726224881861194)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.58})
# ('Accuracy:', 0.5725935214482593)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.59})
# ('Accuracy:', 0.5725646797554989)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.6})
# ('Accuracy:', 0.572535962243478)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.61})
# ('Accuracy:', 0.5725073680555328)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.62})
# ('Accuracy:', 0.5724788963426141)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.63})
# ('Accuracy:', 0.5724505462632059)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.64})
# ('Accuracy:', 0.5724223169832461)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.65})
# ('Accuracy:', 0.572394207676047)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.66})
# ('Accuracy:', 0.5723662175222177)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.67})
# ('Accuracy:', 0.5723383457095863)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.68})
# ('Accuracy:', 0.5723105914331246)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.69})
# ('Accuracy:', 0.5722829538948717)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.7})
# ('Accuracy:', 0.5722554323038603)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.71})
# ('Accuracy:', 0.5722280258760442)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.72})
# ('Accuracy:', 0.5722007338342221)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.73})
# ('Accuracy:', 0.5721735554079705)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.74})
# ('Accuracy:', 0.5721464898335687)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.75})
# ('Accuracy:', 0.5721195363539319)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.7600000000000002})
# ('Accuracy:', 0.5720926942185396)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.77})
# ('Accuracy:', 0.5720659626833677)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.7800000000000002})
# ('Accuracy:', 0.5720393410108224)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.79})
# ('Accuracy:', 0.5720128284696708)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.8000000000000003})
# ('Accuracy:', 0.5719864243349768)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.81})
# ('Accuracy:', 0.5719601278880354)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.82})
# ('Accuracy:', 0.5719339384163074)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.83})
# ('Accuracy:', 0.5719078552133565)
#
# ====================================
# ('Hyperparameter:', {'alpha': 2.84})
# ('Accuracy:', 0.5718818775787862)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.85})
# ('Accuracy:', 0.5718560048181772)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.86})
# ('Accuracy:', 0.571830236243026)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.87})
# ('Accuracy:', 0.5718045711706843)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.88})
# ('Accuracy:', 0.5717790089242987)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.89})
# ('Accuracy:', 0.5717535488327514)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.9})
# ('Accuracy:', 0.5717281902306014)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.91})
# ('Accuracy:', 0.5717029324580265)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.92})
# ('Accuracy:', 0.5716777748607662)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.93})
# ('Accuracy:', 0.5716527167900654)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.94})
# ('Accuracy:', 0.5716277576026165)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.95})
# ('Accuracy:', 0.5716028966605067)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.96})
# ('Accuracy:', 0.571578133331162)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.97})
# ('Accuracy:', 0.5715534669872923)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.98})
# ('Accuracy:', 0.57152889700684)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 2.99})
# ('Accuracy:', 0.5715044227729249)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.0})
# ('Accuracy:', 0.5714800436737941)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.0100000000000002})
# ('Accuracy:', 0.5714557591027689)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.02})
# ('Accuracy:', 0.5714315684581943)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.0300000000000002})
# ('Accuracy:', 0.5714074711433892)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.04})
# ('Accuracy:', 0.5713834665665951)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.0500000000000003})
# ('Accuracy:', 0.5713595541409284)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.06})
# ('Accuracy:', 0.5713357332843307)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.0700000000000003})
# ('Accuracy:', 0.5713120034195217)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.08})
# ('Accuracy:', 0.57128836397395)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.09})
# ('Accuracy:', 0.5712648143797472)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.1})
# ('Accuracy:', 0.5712413540736817)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.11})
# ('Accuracy:', 0.571217982497112)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.12})
# ('Accuracy:', 0.5711946990959413)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.13})
# ('Accuracy:', 0.5711715033205733)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.14})
# ('Accuracy:', 0.5711483946258671)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.15})
# ('Accuracy:', 0.571125372471093)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.16})
# ('Accuracy:', 0.5711024363198903)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.17})
# ('Accuracy:', 0.5710795856402237)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.18})
# ('Accuracy:', 0.5710568199043407)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.19})
# ('Accuracy:', 0.5710341385887292)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.2})
# ('Accuracy:', 0.5710115411740783)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.21})
# ('Accuracy:', 0.5709890271452343)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.22})
# ('Accuracy:', 0.5709665959911625)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.23})
# ('Accuracy:', 0.5709442472049051)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.24})
# ('Accuracy:', 0.5709219802835444)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.25})
# ('Accuracy:', 0.5708997947281602)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.2600000000000002})
# ('Accuracy:', 0.5708776900437945)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.27})
# ('Accuracy:', 0.5708556657394097)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.2800000000000002})
# ('Accuracy:', 0.5708337213278543)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.29})
# ('Accuracy:', 0.5708118563258222)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.3000000000000003})
# ('Accuracy:', 0.5707900702538187)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.31})
# ('Accuracy:', 0.5707683626361211)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.3200000000000003})
# ('Accuracy:', 0.5707467330007446)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.33})
# ('Accuracy:', 0.5707251808794052)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.34})
# ('Accuracy:', 0.5707037058074849)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.35})
# ('Accuracy:', 0.5706823073239967)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.36})
# ('Accuracy:', 0.57066098497155)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.37})
# ('Accuracy:', 0.5706397382963163)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.38})
# ('Accuracy:', 0.5706185668479946)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.39})
# ('Accuracy:', 0.5705974701797795)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.4})
# ('Accuracy:', 0.5705764478483266)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.41})
# ('Accuracy:', 0.5705554994137204)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.42})
# ('Accuracy:', 0.5705346244394428)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.43})
# ('Accuracy:', 0.5705138224923387)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.44})
# ('Accuracy:', 0.5704930931425869)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.45})
# ('Accuracy:', 0.570472435963667)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.46})
# ('Accuracy:', 0.5704518505323293)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.47})
# ('Accuracy:', 0.5704313364285643)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.48})
# ('Accuracy:', 0.5704108932355714)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.49})
# ('Accuracy:', 0.5703905205397302)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.5})
# ('Accuracy:', 0.5703702179305693)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.5100000000000002})
# ('Accuracy:', 0.5703499850007387)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.52})
# ('Accuracy:', 0.57032982134598)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.5300000000000002})
# ('Accuracy:', 0.5703097265650967)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.54})
# ('Accuracy:', 0.5702897002599276)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.5500000000000003})
# ('Accuracy:', 0.5702697420353178)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.56})
# ('Accuracy:', 0.5702498514990909)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.5700000000000003})
# ('Accuracy:', 0.5702300282620216)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.58})
# ('Accuracy:', 0.5702102719378086)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.59})
# ('Accuracy:', 0.5701905821430479)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.6})
# ('Accuracy:', 0.5701709584972057)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.61})
# ('Accuracy:', 0.5701514006225923)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.62})
# ('Accuracy:', 0.570131908144337)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.63})
# ('Accuracy:', 0.5701124806903602)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.64})
# ('Accuracy:', 0.5700931178913506)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.65})
# ('Accuracy:', 0.5700738193807373)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.66})
# ('Accuracy:', 0.5700545847946672)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.67})
# ('Accuracy:', 0.5700354137719792)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.68})
# ('Accuracy:', 0.5700163059541792)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.69})
# ('Accuracy:', 0.5699972609854178)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.7})
# ('Accuracy:', 0.5699782785124643)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.71})
# ('Accuracy:', 0.5699593581846845)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.72})
# ('Accuracy:', 0.5699404996540169)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.73})
# ('Accuracy:', 0.5699217025749495)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.74})
# ('Accuracy:', 0.569902966604497)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.75})
# ('Accuracy:', 0.5698842914021778)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.7600000000000002})
# ('Accuracy:', 0.5698656766299921)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.77})
# ('Accuracy:', 0.5698471219523993)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.7800000000000002})
# ('Accuracy:', 0.5698286270362962)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.79})
# ('Accuracy:', 0.5698101915509962)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.8000000000000003})
# ('Accuracy:', 0.5697918151682053)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.81})
# ('Accuracy:', 0.5697734975620039)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.8200000000000003})
# ('Accuracy:', 0.5697552384088234)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.83})
# ('Accuracy:', 0.5697370373874269)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.84})
# ('Accuracy:', 0.5697188941788878)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.85})
# ('Accuracy:', 0.5697008084665688)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.86})
# ('Accuracy:', 0.5696827799361036)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.87})
# ('Accuracy:', 0.5696648082753757)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.88})
# ('Accuracy:', 0.569646893174498)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.89})
# ('Accuracy:', 0.5696290343257941)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.9})
# ('Accuracy:', 0.5696112314237798)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.91})
# ('Accuracy:', 0.569593484165142)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.92})
# ('Accuracy:', 0.5695757922487208)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.93})
# ('Accuracy:', 0.5695581553754907)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.94})
# ('Accuracy:', 0.5695405732485423)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.95})
# ('Accuracy:', 0.5695230455730633)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.96})
# ('Accuracy:', 0.5695055720563201)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.97})
# ('Accuracy:', 0.5694881524076408)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.98})
# ('Accuracy:', 0.5694707863383967)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 3.99})
# ('Accuracy:', 0.5694534735619847)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.0})
# ('Accuracy:', 0.5694362137938096)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.01})
# ('Accuracy:', 0.5694190067512677)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.0200000000000005})
# ('Accuracy:', 0.569401852153728)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.03})
# ('Accuracy:', 0.5693847497225176)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.04})
# ('Accuracy:', 0.5693676991809027)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.05})
# ('Accuracy:', 0.5693507002540735)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.0600000000000005})
# ('Accuracy:', 0.5693337526691269)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.07})
# ('Accuracy:', 0.5693168561550505)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.08})
# ('Accuracy:', 0.5693000104427065)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.09})
# ('Accuracy:', 0.5692832152648162)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.1})
# ('Accuracy:', 0.5692664703559435)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.11})
# ('Accuracy:', 0.5692497754524791)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.12})
# ('Accuracy:', 0.5692331302926263)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.13})
# ('Accuracy:', 0.5692165346163842)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.14})
# ('Accuracy:', 0.5691999881655337)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.15})
# ('Accuracy:', 0.5691834906836215)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.16})
# ('Accuracy:', 0.5691670419159465)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.17})
# ('Accuracy:', 0.5691506416095432)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.18})
# ('Accuracy:', 0.5691342895131691)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.19})
# ('Accuracy:', 0.5691179853772894)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.2})
# ('Accuracy:', 0.5691017289540617)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.21})
# ('Accuracy:', 0.5690855199973242)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.22})
# ('Accuracy:', 0.5690693582625796)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.23})
# ('Accuracy:', 0.5690532435069822)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.24})
# ('Accuracy:', 0.5690371754893236)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.25})
# ('Accuracy:', 0.5690211539700203)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.26})
# ('Accuracy:', 0.569005178711099)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.2700000000000005})
# ('Accuracy:', 0.568989249476183)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.28})
# ('Accuracy:', 0.5689733660304805)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.29})
# ('Accuracy:', 0.5689575281407707)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 4.3})
# ('Accuracy:', 0.5689417355753905)
#
# ====================================
#
# ...
#
# ('Hyperparameter:', {'alpha': 8.57})
# ('Accuracy:', 0.5645859020946296)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.58})
# ('Accuracy:', 0.5645789164050079)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.59})
# ('Accuracy:', 0.564571939329312)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.6})
# ('Accuracy:', 0.5645649708417166)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.61})
# ('Accuracy:', 0.5645580109164989)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.620000000000001})
# ('Accuracy:', 0.5645510595280373)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.63})
# ('Accuracy:', 0.5645441166508121)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.64})
# ('Accuracy:', 0.5645371822594034)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.65})
# ('Accuracy:', 0.5645302563284929)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.66})
# ('Accuracy:', 0.5645233388328611)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.67})
# ('Accuracy:', 0.5645164297473881)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.68})
# ('Accuracy:', 0.5645095290470528)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.69})
# ('Accuracy:', 0.5645026367069323)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.700000000000001})
# ('Accuracy:', 0.564495752702202)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.71})
# ('Accuracy:', 0.564488877008134)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.72})
# ('Accuracy:', 0.5644820096000975)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.73})
# ('Accuracy:', 0.5644751504535589)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.74})
# ('Accuracy:', 0.5644682995440795)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.75})
# ('Accuracy:', 0.5644614568473165)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.76})
# ('Accuracy:', 0.5644546223390223)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.77})
# ('Accuracy:', 0.5644477959950438)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.78})
# ('Accuracy:', 0.564440977791322)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.790000000000001})
# ('Accuracy:', 0.5644341677038913)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.8})
# ('Accuracy:', 0.5644273657088795)
#
# ====================================
# ('Hyperparameter:', {'alpha': 8.81})
# ('Accuracy:', 0.5644205717825077)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.82})
# ('Accuracy:', 0.5644137859010884)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.83})
# ('Accuracy:', 0.5644070080410266)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.84})
# ('Accuracy:', 0.5644002381788185)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.85})
# ('Accuracy:', 0.5643934762910515)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.86})
# ('Accuracy:', 0.5643867223544035)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.870000000000001})
# ('Accuracy:', 0.5643799763456421)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.88})
# ('Accuracy:', 0.5643732382416249)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.89})
# ('Accuracy:', 0.564366508019299)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.9})
# ('Accuracy:', 0.5643597856557003)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.91})
# ('Accuracy:', 0.564353071127953)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.92})
# ('Accuracy:', 0.564346364413269)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.93})
# ('Accuracy:', 0.5643396654889481)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.94})
# ('Accuracy:', 0.5643329743323773)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.950000000000001})
# ('Accuracy:', 0.5643262909210303)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.96})
# ('Accuracy:', 0.564319615232467)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.97})
# ('Accuracy:', 0.5643129472443332)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.98})
# ('Accuracy:', 0.5643062869343606)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 8.99})
# ('Accuracy:', 0.5642996342803657)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.0})
# ('Accuracy:', 0.5642929892602496)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.01})
# ('Accuracy:', 0.564286351851998)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.02})
# ('Accuracy:', 0.5642797220336804)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.03})
# ('Accuracy:', 0.5642730997834496)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.040000000000001})
# ('Accuracy:', 0.5642664850795424)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.05})
# ('Accuracy:', 0.5642598779002769)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.06})
# ('Accuracy:', 0.5642532782240544)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.07})
# ('Accuracy:', 0.5642466860293585)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.08})
# ('Accuracy:', 0.5642401012947533)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.09})
# ('Accuracy:', 0.5642335239988855)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.1})
# ('Accuracy:', 0.5642269541204814)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.11})
# ('Accuracy:', 0.5642203916383481)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.120000000000001})
# ('Accuracy:', 0.5642138365313729)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.13})
# ('Accuracy:', 0.5642072887785226)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.14})
# ('Accuracy:', 0.5642007483588438)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.15})
# ('Accuracy:', 0.5641942152514614)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.16})
# ('Accuracy:', 0.5641876894355788)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.17})
# ('Accuracy:', 0.5641811708904785)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.18})
# ('Accuracy:', 0.5641746595955196)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.19})
# ('Accuracy:', 0.5641681555301399)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.200000000000001})
# ('Accuracy:', 0.5641616586738535)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.21})
# ('Accuracy:', 0.5641551690062512)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.22})
# ('Accuracy:', 0.5641486865070011)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.23})
# ('Accuracy:', 0.5641422111558465)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.24})
# ('Accuracy:', 0.5641357429326066)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.25})
# ('Accuracy:', 0.5641292818171764)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.26})
# ('Accuracy:', 0.5641228277895247)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.27})
# ('Accuracy:', 0.5641163808296966)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.28})
# ('Accuracy:', 0.5641099409178102)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.290000000000001})
# ('Accuracy:', 0.5641035080340584)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.3})
# ('Accuracy:', 0.5640970821587068)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.31})
# ('Accuracy:', 0.5640906632720953)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.32})
# ('Accuracy:', 0.5640842513546362)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.33})
# ('Accuracy:', 0.5640778463868147)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.34})
# ('Accuracy:', 0.5640714483491878)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.35})
# ('Accuracy:', 0.564065057222385)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.36})
# ('Accuracy:', 0.5640586729871071)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.370000000000001})
# ('Accuracy:', 0.5640522956241261)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.38})
# ('Accuracy:', 0.5640459251142855)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.39})
# ('Accuracy:', 0.564039561438499)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.4})
# ('Accuracy:', 0.5640332045777504)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.41})
# ('Accuracy:', 0.5640268545130942)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.42})
# ('Accuracy:', 0.5640205112256542)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.43})
# ('Accuracy:', 0.5640141746966234)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.44})
# ('Accuracy:', 0.5640078449072641)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.450000000000001})
# ('Accuracy:', 0.564001521838907)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.46})
# ('Accuracy:', 0.563995205472952)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.47})
# ('Accuracy:', 0.5639888957908663)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.48})
# ('Accuracy:', 0.5639825927741853)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.49})
# ('Accuracy:', 0.5639762964045116)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.5})
# ('Accuracy:', 0.5639700066635156)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.51})
# ('Accuracy:', 0.563963723532934)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.52})
# ('Accuracy:', 0.5639574469945701)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.53})
# ('Accuracy:', 0.5639511770302938)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.540000000000001})
# ('Accuracy:', 0.5639449136220414)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.55})
# ('Accuracy:', 0.5639386567518134)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.56})
# ('Accuracy:', 0.5639324064016774)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.57})
# ('Accuracy:', 0.563926162553765)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.58})
# ('Accuracy:', 0.5639199251902731)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.59})
# ('Accuracy:', 0.5639136942934634)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.6})
# ('Accuracy:', 0.5639074698456606)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.61})
# ('Accuracy:', 0.563901251829255)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.620000000000001})
# ('Accuracy:', 0.5638950402266991)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.63})
# ('Accuracy:', 0.5638888350205096)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.64})
# ('Accuracy:', 0.5638826361932663)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.65})
# ('Accuracy:', 0.5638764437276114)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.66})
# ('Accuracy:', 0.5638702576062502)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.67})
# ('Accuracy:', 0.5638640778119492)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.68})
# ('Accuracy:', 0.5638579043275382)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.69})
# ('Accuracy:', 0.5638517371359077)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.700000000000001})
# ('Accuracy:', 0.5638455762200102)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.71})
# ('Accuracy:', 0.5638394215628589)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.72})
# ('Accuracy:', 0.5638332731475283)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.73})
# ('Accuracy:', 0.5638271309571533)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.74})
# ('Accuracy:', 0.5638209949749291)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.75})
# ('Accuracy:', 0.5638148651841113)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.76})
# ('Accuracy:', 0.5638087415680144)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.77})
# ('Accuracy:', 0.5638026241100138)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.78})
# ('Accuracy:', 0.5637965127935431)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.790000000000001})
# ('Accuracy:', 0.5637904076020954)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.8})
# ('Accuracy:', 0.5637843085192225)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.81})
# ('Accuracy:', 0.5637782155285342)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.82})
# ('Accuracy:', 0.5637721286136996)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.83})
# ('Accuracy:', 0.563766047758445)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.84})
# ('Accuracy:', 0.5637599729465546)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.85})
# ('Accuracy:', 0.56375390416187)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.86})
# ('Accuracy:', 0.5637478413882901)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.870000000000001})
# ('Accuracy:', 0.5637417846097713)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.88})
# ('Accuracy:', 0.5637357338103254)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.89})
# ('Accuracy:', 0.5637296889740222)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.9})
# ('Accuracy:', 0.5637236500849869)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.91})
# ('Accuracy:', 0.5637176171274006)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.92})
# ('Accuracy:', 0.5637115900855005)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.93})
# ('Accuracy:', 0.5637055689435793)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.94})
# ('Accuracy:', 0.563699553685985)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.950000000000001})
# ('Accuracy:', 0.56369354429712)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.96})
# ('Accuracy:', 0.5636875407614423)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.97})
# ('Accuracy:', 0.5636815430634639)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.98})
# ('Accuracy:', 0.5636755511877516)
#
# ====================================
#
# ('Hyperparameter:', {'alpha': 9.99})
# ('Accuracy:', 0.5636695651189255)
#
# ====================================
#
# Best Hyperparameters for KNearest: {'n_neighbors': 6, 'weights': 'distance'}

# %% [markdown]
# ### In above results we can how the accuracy score changes when we change the hyper-parameters and as per the score we can tune them!

# %% [markdown]
# ### Now lets test SVM on our hyper-parameter space that you created

# %%
# you code goes here

# %% [markdown]
# # Using scikit learn for Hyper-parameter tuning(examples and exercises)
